# %%
#%tensorflow_version 2.x

from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import sys
projectDir = "/content/drive/MyDrive/data/tweepfake_deepfake_text_detection"
sys.path.insert(0, projectDir)

random_state = 523 # Fixed seed for replicability of randomic operations.
resultsDir = projectDir+"/data/results"

# %%
# %%writefile setup.sh
#
# export CUDA_HOME=/usr/local/cuda-10.1
# git clone https://github.com/NVIDIA/apex
# pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./apex
# Out:
# Writing setup.sh

# %%
# !sh setup.sh
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 9562, done.
# remote: Counting objects: 100% (633/633), done.
# remote: Compressing objects: 100% (426/426), done.
# remote: Total 9562 (delta 362), reused 383 (delta 191), pack-reused 8929
# Receiving objects: 100% (9562/9562), 14.82 MiB | 22.68 MiB/s, done.
# Resolving deltas: 100% (6475/6475), done.
# /usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py:232: UserWarning: Disabling all use of wheels due to the use of --build-option / --global-option / --install-option.
#   cmdoptions.check_install_build_global(options)
# Using pip 21.1.3 from /usr/local/lib/python3.7/dist-packages/pip (python 3.7)
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.7/UNKNOWN
# sysconfig: /usr/include/python3.7m/UNKNOWN
# Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local
# sysconfig: /usr
# Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Non-user install because site-packages writeable
# Created temporary directory: /tmp/pip-ephem-wheel-cache-qblikzqf
# Created temporary directory: /tmp/pip-req-tracker-7rvc5utg
# Initialized build tracking at /tmp/pip-req-tracker-7rvc5utg
# Created build tracker: /tmp/pip-req-tracker-7rvc5utg
# Entered build tracker: /tmp/pip-req-tracker-7rvc5utg
# Created temporary directory: /tmp/pip-install-4llh_2ff
# Processing ./apex
#   Created temporary directory: /tmp/pip-req-build-kloscvtt
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
#   Added file:///content/apex to build tracker '/tmp/pip-req-tracker-7rvc5utg'
#     Running setup.py (path:/tmp/pip-req-build-kloscvtt/setup.py) egg_info for package from file:///content/apex
#     Created temporary directory: /tmp/pip-pip-egg-info-286l9o45
#     Running command python setup.py egg_info
#
#
#     torch.__version__  = 1.10.0+cu111
#
#
#     running egg_info
#     creating /tmp/pip-pip-egg-info-286l9o45/apex.egg-info
#     writing /tmp/pip-pip-egg-info-286l9o45/apex.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-286l9o45/apex.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-286l9o45/apex.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-286l9o45/apex.egg-info/SOURCES.txt'
#     adding license file 'LICENSE'
#     writing manifest file '/tmp/pip-pip-egg-info-286l9o45/apex.egg-info/SOURCES.txt'
#     /tmp/pip-req-build-kloscvtt/setup.py:109: UserWarning: Option --pyprof not specified. Not installing PyProf dependencies!
#       warnings.warn("Option --pyprof not specified. Not installing PyProf dependencies!")
#   Source in /tmp/pip-req-build-kloscvtt has version 0.1, which satisfies requirement apex==0.1 from file:///content/apex
#   Removed apex==0.1 from file:///content/apex from build tracker '/tmp/pip-req-tracker-7rvc5utg'
# Created temporary directory: /tmp/pip-unpack-9f_27kg7
# Skipping wheel build for apex, due to binaries being disabled for it.
# Installing collected packages: apex
#   Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/include/python3.7/apex
#   sysconfig: /usr/include/python3.7m/apex
#   Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/bin
#   sysconfig: /usr/bin
#   Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local
#   sysconfig: /usr
#   Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = None
#   Created temporary directory: /tmp/pip-record-2x5o098z
#     Running command /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-req-build-kloscvtt/setup.py'"'"'; __file__='"'"'/tmp/pip-req-build-kloscvtt/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' --cpp_ext --cuda_ext install --record /tmp/pip-record-2x5o098z/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7/apex
#
#
#     torch.__version__  = 1.10.0+cu111
#
#
#     /tmp/pip-req-build-kloscvtt/setup.py:109: UserWarning: Option --pyprof not specified. Not installing PyProf dependencies!
#       warnings.warn("Option --pyprof not specified. Not installing PyProf dependencies!")
#
#     Compiling cuda extensions with
#     nvcc: NVIDIA (R) Cuda compiler driver
#     Copyright (c) 2005-2019 NVIDIA Corporation
#     Built on Sun_Jul_28_19:07:16_PDT_2019
#     Cuda compilation tools, release 10.1, V10.1.243
#     from /usr/local/cuda-10.1/bin
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-req-build-kloscvtt/setup.py", line 177, in <module>
#         check_cuda_torch_binary_vs_bare_metal(CUDA_HOME)
#       File "/tmp/pip-req-build-kloscvtt/setup.py", line 38, in check_cuda_torch_binary_vs_bare_metal
#         + "In some cases, a minor-version mismatch will not cause later errors:  "
#     RuntimeError: Cuda extensions are being compiled with a version of Cuda that does not match the version used to compile Pytorch binaries.  Pytorch binaries were compiled with Cuda 11.1.
#     In some cases, a minor-version mismatch will not cause later errors:  https://github.com/NVIDIA/apex/pull/323#discussion_r287021798.  You can try commenting out this check (at your own risk).
#     Running setup.py install for apex ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-req-build-kloscvtt/setup.py'"'"'; __file__='"'"'/tmp/pip-req-build-kloscvtt/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' --cpp_ext --cuda_ext install --record /tmp/pip-record-2x5o098z/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7/apex Check the logs for full command output.
# Exception information:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/req/req_install.py", line 825, in install
#     req_description=str(self.req),
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/operations/install/legacy.py", line 81, in install
#     raise LegacyInstallFailure
# pip._internal.operations.install.legacy.LegacyInstallFailure
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/base_command.py", line 180, in _main
#     status = self.run(options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/req_command.py", line 199, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py", line 402, in run
#     pycompile=options.compile,
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/req/__init__.py", line 85, in install_given_reqs
#     pycompile=pycompile,
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/req/req_install.py", line 829, in install
#     six.reraise(*exc.parent)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/six.py", line 703, in reraise
#     raise value
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/operations/install/legacy.py", line 71, in install
#     cwd=unpacked_source_directory,
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/utils/subprocess.py", line 278, in runner
#     spinner=spinner,
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/utils/subprocess.py", line 244, in call_subprocess
#     raise InstallationSubprocessError(proc.returncode, command_desc)
# pip._internal.exceptions.InstallationSubprocessError: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-req-build-kloscvtt/setup.py'"'"'; __file__='"'"'/tmp/pip-req-build-kloscvtt/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' --cpp_ext --cuda_ext install --record /tmp/pip-record-2x5o098z/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7/apex Check the logs for full command output.
# Removed build tracker: '/tmp/pip-req-tracker-7rvc5utg'

# %%
# !pip install pandas transformers simpletransformers==0.41 amp
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 7.6 MB/s
# Collecting simpletransformers==0.41
#   Downloading simpletransformers-0.41.0-py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 63.6 MB/s
# Collecting amp
#   Downloading AMP-1.1.4.tar.gz (8.0 kB)
# Collecting tensorboardx
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 59.8 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from simpletransformers==0.41) (1.21.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from simpletransformers==0.41) (2.23.0)
# Collecting tokenizers<=0.7
#   Downloading tokenizers-0.7.0-cp37-cp37m-manylinux1_x86_64.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 47.9 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from simpletransformers==0.41) (1.4.1)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.0 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from simpletransformers==0.41) (4.63.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from simpletransformers==0.41) (1.0.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from simpletransformers==0.41) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 61.5 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 50.2 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 8.6 MB/s
# Collecting transformers
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 49.3 MB/s
#   Downloading transformers-4.16.2-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 47.3 MB/s
#   Downloading transformers-4.16.1-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 42.4 MB/s
#   Downloading transformers-4.16.0-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 42.9 MB/s
#   Downloading transformers-4.15.0-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 46.8 MB/s
#   Downloading transformers-4.14.1-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 51.6 MB/s
#   Downloading transformers-4.13.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 50.7 MB/s
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 48.0 MB/s
#   Downloading transformers-4.12.4-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 46.6 MB/s
#   Downloading transformers-4.12.3-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 44.5 MB/s
#   Downloading transformers-4.12.2-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 41.0 MB/s
#   Downloading transformers-4.12.1-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 43.1 MB/s
#   Downloading transformers-4.12.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 46.3 MB/s
#   Downloading transformers-4.11.3-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 46.3 MB/s
#   Downloading transformers-4.11.2-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 42.7 MB/s
#   Downloading transformers-4.11.1-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 48.0 MB/s
#   Downloading transformers-4.11.0-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 41.6 MB/s
#   Downloading transformers-4.10.3-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 39.1 MB/s
#   Downloading transformers-4.10.2-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 46.3 MB/s
#   Downloading transformers-4.10.1-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 46.2 MB/s
#   Downloading transformers-4.10.0-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 49.5 MB/s
#   Downloading transformers-4.9.2-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 44.6 MB/s
#   Downloading transformers-4.9.1-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 48.2 MB/s
#   Downloading transformers-4.9.0-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 44.9 MB/s
#   Downloading transformers-4.8.2-py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 46.2 MB/s
#   Downloading transformers-4.8.1-py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 49.5 MB/s
#   Downloading transformers-4.8.0-py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 46.9 MB/s
#   Downloading transformers-4.7.0-py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 48.1 MB/s
#   Downloading transformers-4.6.1-py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 48.5 MB/s
#   Downloading transformers-4.6.0-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 49.5 MB/s
#   Downloading transformers-4.5.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 32.7 MB/s
#   Downloading transformers-4.5.0-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 36.3 MB/s
#   Downloading transformers-4.4.2-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 48.9 MB/s
#   Downloading transformers-4.4.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 52.3 MB/s
#   Downloading transformers-4.4.0-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 45.5 MB/s
#   Downloading transformers-4.3.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 46.0 MB/s
#   Downloading transformers-4.3.2-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 47.9 MB/s
#   Downloading transformers-4.3.1-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 50.3 MB/s
#   Downloading transformers-4.3.0-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 50.2 MB/s
#   Downloading transformers-4.2.2-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 50.0 MB/s
#   Downloading transformers-4.2.1-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 49.9 MB/s
#   Downloading transformers-4.2.0-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 50.7 MB/s
#   Downloading transformers-4.1.1-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 50.0 MB/s
#   Downloading transformers-4.1.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 54.3 MB/s
#   Downloading transformers-4.0.1-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 49.6 MB/s
#   Downloading transformers-4.0.0-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 50.5 MB/s
#   Downloading transformers-3.5.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 47.1 MB/s
#   Downloading transformers-3.5.0-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 50.3 MB/s
#   Downloading transformers-3.4.0-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 43.3 MB/s
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from transformers) (3.17.3)
#   Downloading transformers-3.3.1-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 48.4 MB/s
#   Downloading transformers-3.3.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 42.3 MB/s
#   Downloading transformers-3.2.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 53.5 MB/s
#   Downloading transformers-3.1.0-py3-none-any.whl (884 kB)
#      |████████████████████████████████| 884 kB 57.8 MB/s
#   Downloading transformers-3.0.2-py3-none-any.whl (769 kB)
#      |████████████████████████████████| 769 kB 62.0 MB/s
# Collecting sentencepiece!=0.1.92
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 57.7 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Collecting transformers
#   Downloading transformers-3.0.1-py3-none-any.whl (757 kB)
#      |████████████████████████████████| 757 kB 70.7 MB/s
#   Downloading transformers-3.0.0-py3-none-any.whl (754 kB)
#      |████████████████████████████████| 754 kB 62.7 MB/s
#   Downloading transformers-2.11.0-py3-none-any.whl (674 kB)
#      |████████████████████████████████| 674 kB 56.8 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Collecting Django>=1.1.1
#   Downloading Django-3.2.12-py3-none-any.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 53.0 MB/s
# Collecting caldav==0.1.4
#   Downloading caldav-0.1.4.tar.gz (8.5 kB)
# Collecting vobject
#   Downloading vobject-0.9.6.1.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 6.9 MB/s
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from caldav==0.1.4->amp) (4.2.6)
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 59.9 MB/s
# Requirement already satisfied: coverage in /usr/local/lib/python3.7/dist-packages (from caldav==0.1.4->amp) (3.7.1)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from Django>=1.1.1->amp) (0.4.2)
# Collecting asgiref<4,>=3.3.2
#   Downloading asgiref-3.5.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from asgiref<4,>=3.3.2->Django>=1.1.1->amp) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (3.0.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers==0.41) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers==0.41) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers==0.41) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers==0.41) (2.10)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->simpletransformers==0.41) (3.1.0)
# Building wheels for collected packages: amp, caldav, seqeval, vobject
#   Building wheel for amp (setup.py) ... done
#   Created wheel for amp: filename=AMP-1.1.4-py3-none-any.whl size=9417 sha256=e38670adc9c920dd5394cc6525554394295687f83ed3ca29bf6f72cc696546d6
#   Stored in directory: /root/.cache/pip/wheels/f1/85/a9/b910bdd74f0155896835c82126f844464a31213eb72ec30c9f
#   Building wheel for caldav (setup.py) ... done
#   Created wheel for caldav: filename=caldav-0.1.4-py3-none-any.whl size=12305 sha256=358594b7ddf56515bb2e6c302830ed116c7b14e077b223ecde4cc9297dcd916f
#   Stored in directory: /root/.cache/pip/wheels/42/1d/f8/c6e4a8fd44d4f8ad6f288a79b6e56c0fd5a5b0f5d3c52a07aa
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=73e62d00f7649fcbc17cfd17182ee0b299c16cb56d321871099b5c679e310af8
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for vobject (setup.py) ... done
#   Created wheel for vobject: filename=vobject-0.9.6.1-py3-none-any.whl size=47683 sha256=0a33aa3de17a8c1ea838bb9e33c5b7641d6431c83aa4dfff27a7958a9b662be7
#   Stored in directory: /root/.cache/pip/wheels/94/dc/9c/8d995b5e42e6c351a2abaf8e9bab49a4e0ca2bb24017f1473d
# Successfully built amp caldav seqeval vobject
# Installing collected packages: vobject, tokenizers, sentencepiece, sacremoses, nose, asgiref, transformers, tensorboardx, seqeval, Django, caldav, simpletransformers, amp
# Successfully installed Django-3.2.12 amp-1.1.4 asgiref-3.5.0 caldav-0.1.4 nose-1.3.7 sacremoses-0.0.49 sentencepiece-0.1.96 seqeval-1.2.2 simpletransformers-0.41.0 tensorboardx-2.5 tokenizers-0.7.0 transformers-2.11.0 vobject-0.9.6.1

# %%
# from DataHandler import DataHandler
import pandas as pd

csvTrainDataset = projectDir+"/data/splits/train.csv"
csvValDataset = projectDir+"/data/splits/validation.csv"
csvTestDataset = projectDir+"/data/splits/test.csv"

bertDir = projectDir+"/data/encoded/bert"
# dh = DataHandler()
# dfTrain = dh.readCSVData(csvTrainDataset)
# dfVal = dh.readCSVData(csvValDataset)
# dfTest = dh.readCSVData(csvTestDataset)
dfTrain = pd.read_csv(csvTrainDataset, sep=';')
dfVal = pd.read_csv(csvValDataset, sep=';')
dfTest = pd.read_csv(csvTestDataset, sep=';')

# %%
dfTrain
# Out:
#           screen_name                                               text  \
# 0          imranyebot                             YEA now that note GOOD
# 1              zawvrk  Listen to This Charming Man by The Smiths  htt...
# 2            zawarbot  wish i can i would be seeing other hoes on the...
# 3      ahadsheriffbot  The decade in the significantly easier schedul...
# 4       kevinhookebot  "Theim class=\"alignnone size-full wp-image-60...
# ...               ...                                                ...
# 20707  AINarendraModi  Met on the Abversion of our science for the co...
# 20708  AINarendraModi  Land for their during the opportunity to the p...
# 20709      DeepDrumpf  @TayandYou doesn't have a clue. You're right. ...
# 20710           jaden           Me And My Bestie https://t.co/vPq2iDkWZm
# 20711   kevinhookebot  "Thead has a generate existing the Sparching f...
#
#       account.type class_type
# 0              bot     others
# 1            human      human
# 2              bot     others
# 3              bot     others
# 4              bot        rnn
# ...            ...        ...
# 20707          bot        rnn
# 20708          bot        rnn
# 20709          bot        rnn
# 20710        human      human
# 20711          bot        rnn
#
# [20712 rows x 4 columns]

# %%
# Select interesting columns for this study.
dfTrainDataset = dfTrain[["screen_name", "text", "account.type"]]
dfValDataset = dfVal[["screen_name", "text", "account.type"]]
dfTestDataset = dfTest[["screen_name", "text", "account.type"]]

# %%
dfTrainDataset
# Out:
#           screen_name                                               text  \
# 0          imranyebot                             YEA now that note GOOD
# 1              zawvrk  Listen to This Charming Man by The Smiths  htt...
# 2            zawarbot  wish i can i would be seeing other hoes on the...
# 3      ahadsheriffbot  The decade in the significantly easier schedul...
# 4       kevinhookebot  "Theim class=\"alignnone size-full wp-image-60...
# ...               ...                                                ...
# 20707  AINarendraModi  Met on the Abversion of our science for the co...
# 20708  AINarendraModi  Land for their during the opportunity to the p...
# 20709      DeepDrumpf  @TayandYou doesn't have a clue. You're right. ...
# 20710           jaden           Me And My Bestie https://t.co/vPq2iDkWZm
# 20711   kevinhookebot  "Thead has a generate existing the Sparching f...
#
#       account.type
# 0              bot
# 1            human
# 2              bot
# 3              bot
# 4              bot
# ...            ...
# 20707          bot
# 20708          bot
# 20709          bot
# 20710        human
# 20711          bot
#
# [20712 rows x 3 columns]

# %%
X_train_all = dfTrainDataset.drop(columns=['screen_name'])
X_train_all.columns = ["text", "label"]

X_val_all = dfValDataset.drop(columns=['screen_name'])
X_val_all.columns = ["text", "label"]

X_test_all = dfTestDataset.drop(columns=['screen_name'])
X_test_all.columns = ["text", "label"]

dictLabels = {"human":0, "bot":1}
dictLabelsReverse = {0:"human", 1: "bot"}

X_train_all["label"] = X_train_all["label"].apply(lambda x: dictLabels[x])
X_val_all["label"] = X_val_all["label"].apply(lambda x: dictLabels[x])
X_test_all["label"] = X_test_all["label"].apply(lambda x: dictLabels[x])
y_train = X_train_all["label"]
y_val = X_val_all["label"]
y_test = X_test_all["label"]

# %%
train_labels = y_train.tolist()
val_labels = y_val.tolist()
test_labels = y_test.tolist()

# %%
from simpletransformers.classification import ClassificationModel

# Create a ClassificationModel
model = ClassificationModel('bert', 'bert-base-cased', args={'fp16': False, 'num_train_epochs': 3, "overwrite_output_dir":True}) # You can set class weights by using the optional weight argument

# Train the model
model.train_model(X_train_all)
# Out:
# Downloading:   0%|          | 0.00/433 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:270: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/20712 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 14 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch:   0%|          | 0/3 [00:00<?, ?it/s]
# Running Epoch 0:   0%|          | 0/2589 [00:00<?, ?it/s]
# Running loss: 0.796930
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:247: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Running loss: 0.263126
# Running Epoch 1:   0%|          | 0/2589 [00:00<?, ?it/s]
# Running loss: 0.014489
# Running Epoch 2:   0%|          | 0/2589 [00:00<?, ?it/s]
# Running loss: 0.000716

# %%
# Evaluate the model
import sklearn
result, model_outputs, wrong_predictions = model.eval_model(X_test_all, acc=sklearn.metrics.accuracy_score, f1=sklearn.metrics.f1_score)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:691: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/2558 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f648cd90f80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f648cd90f80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f648cd90f80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Running Evaluation:   0%|          | 0/320 [00:00<?, ?it/s]

# %%
result
# Out:
# {'acc': 0.8928850664581705,
#  'eval_loss': 0.5467603741922176,
#  'f1': 0.8928850664581705,
#  'fn': 138,
#  'fp': 136,
#  'mcc': 0.7857712245696401,
#  'tn': 1142,
#  'tp': 1142}

# %%
predictions = model.predict(X_test_all["text"])[0]
# Out:
#   0%|          | 0/2558 [00:00<?, ?it/s]
#   0%|          | 0/320 [00:00<?, ?it/s]

# %%
import pandas as pd
predictionLabels = [dictLabelsReverse[t] for t in predictions]
dfResults = pd.DataFrame(predictionLabels, columns=["prediction"])
dfResults["gold"] = dfTest[["account.type"]]
# file_name = resultsDir+"/bert_finetuning.csv"
# dfResults.to_csv(file_name, sep='\t', encoding='utf-8')

# %%
dfTest["label_bert"] = [dictLabelsReverse[t] for t in predictions]

# %%
dfResults.head()
# Out:
#   prediction   gold
# 0      human  human
# 1      human  human
# 2        bot  human
# 3        bot    bot
# 4      human  human

# %%
def plotErrorRatio(X_test_all, prediction_column, min_sample_num=30):
  X_verify = X_test_all[["screen_name", "text", "account.type", prediction_column]]
  X_count_accounts = X_test_all[["screen_name", "account.type"]].groupby("screen_name").count()
  X_verify = X_verify[X_verify["account.type"] != X_verify[prediction_column]]
  X_verify = X_verify.groupby("screen_name").count()["text"].to_frame()
  X_verify["total"] = X_count_accounts["account.type"]
  X_verify.columns = ["errors", "num_samples"]
  X_verify["error_ratio"] = X_verify["errors"] / X_verify["num_samples"]
  X_verify[X_verify["num_samples"] >= min_sample_num]["error_ratio"].plot.bar(figsize=(15,5))
  return X_verify

# %%
plotErrorRatio(dfTest, "label_bert")
# Out:
#                  errors  num_samples  error_ratio
# screen_name
# DeepDrumpf            1           29     0.034483
# GenePark              1           22     0.045455
# GenePark_GPT2         8           22     0.363636
# Gpt2Wint              2            2     1.000000
# Musk_from_Mars        1            2     0.500000
# Thorin                1           10     0.100000
# UtilityLimb           2            4     0.500000
# VBoterin              2           13     0.153846
# ahadsheriff          17           95     0.178947
# ahadsheriffbot        4           95     0.042105
# awhalefact            3           35     0.085714
# botustrump            5           35     0.142857
# calebgamman           5           13     0.384615
# calebgamman2          6           13     0.461538
# deep_thorin           1           10     0.100000
# dril                 50          180     0.277778
# dril_gpt2            69          179     0.385475
# elonmusk              1            6     0.166667
# gpt2_trump           13           55     0.236364
# imranye               7          129     0.054264
# imranyebot            7          129     0.054264
# jaden                 7           51     0.137255
# kevinhooke            2          241     0.008299
# narendramodi          1          124     0.008065
# ninjasexparty         9           23     0.391304
# nsp_gpt2              5           23     0.217391
# realDonaldTrump       9          129     0.069767
# sarcastic_trump       1            5     0.200000
# theJadenTrudeau       3          103     0.029126
# whalefakes            1           35     0.028571
# zawarbot              9          152     0.059211
# zawvrk               21          152     0.138158
